% %% [markdown]
% # <center>Universidad Nacional Agraria La Molina</center>
% ## <center>Facultad de Ciencias -- Departamento de Matemática</center>
% ### <center>Lista de ejercicios $N^{\circ}1$</center>
%
% 1. Almacenar en la variable $\mathbf{b}$ la matriz columna que representa al vector $\left(8, -7, 6, 3, 4\right)$.
%
% Acceder
%
% a. a los elementos $b_i\,\forall i\in\left\{1,2,3\right\}$.
%
% b. al vector con entradas $b_2$, $b_3$ y $b_4$.
%
% 2. Almacenar en la variable $A$ la matriz $$ \begin{bmatrix}7 & 3 & 5 & 6\\3 & 4 & 4 & 2\\ 1 & -1 & 2 & -5\end{bmatrix}$$
%
% Acceder a
%
% a. los elementos $a_{ij}$, $i=1,2,3$ y $j=1,2,3,4$.
%
% b. cada una de las filas de $A$.
%
% c. cada una de las columnas de $A$.
%
% d. la submatriz que se obtiene eliminando la primera fila y las dos primeras columnas.
%
% 3. Generar el vector $\mathbf{x}=\left(x_0,x_1,\ldots,x_{12}\right)$ con entradas $x_i=2+\dfrac{i}{4}$, donde $i=0,1,2,\ldots,12$.
%
% 4. ¿Qué matriz produce la siguiente expresión? ¿Es posible calcular su determinante? ¿Tiene inversa? ¿La matriz $C$ y su transpuesta tienen el mismo determinante?
%
% Use $\det(C)$ para calcular la determinante e $\mathrm{inv}(C)$ para su inversa.
%
% 5. Dados los vectores de $\mathbb{R}^6\colon u=\left(4,3,1,-4,2,3\right), v=\left(11,1,2,4,5,7\right)$ y $w=\left(2,4,-3,5,11\right)$.
%
% Calcular
%
% a. $u\cdot v$, usando producto de matrices.
%
% b. $v\cdot u$, usando el comando `dot(u,v)`.
%
% c. $u^2, w^2, \left(u+v\right)\cdot w, \left(u\cdot v\right)w$.
%
% d. ${\|u\|}_2,{\|u\|}_1,{\|u\|}_\infty,{\|u\|}_5$.
%
% 6. Dadas las matrices
% $$
% A=\begin{bmatrix}4 & 2 & -2\\2 & 1 & 3\end{bmatrix},\quad B=\begin{bmatrix}4 & 2 & 1\\3 & 5 & 3\\7 & 1 & 4\end{bmatrix}\text{ y }C=\begin{bmatrix}1 & 3 & -2\\8&3 & 3\\6 & 5 &2\end{bmatrix}.
% $$
% En los casos que sea posible, calcular según indique. En los casos donde no sea posible, ¡indique las razones!
%
% a. $A^2, AB, B^2, BC, A+B, B+C$ usando las operaciones usuales.
%
% b. $A^2, AB, B^2, BC, A+B, B+C$ usando operaciones elemento a elemento.
%
% c. $A+2, 4B-5$. ¿Qué ocurre?
%
% 7. Dadas las matrices $$A=\begin{bmatrix}2 & 3\\-1&2\end{bmatrix},\quad B=\begin{bmatrix}2 & 4\\3 & -1\end{bmatrix}.$$ Calcular $A/B, A\backslash B, A.\backslash B$ y $A./B$.
%
% 8. Dadas las matrices $$A=\begin{bmatrix}-2 3 5\end{bmatrix},\quad B=\begin{bmatrix}3 & 1\\2 & 4\\6 & 3\end{bmatrix}$$. Calcular $\cos A, \sqrt{A}, e^A, A^A$, ¿algún comenttario?.
%
% 9. Discretizar el intervalo $\left[0,2\right]$ con longitud de paso constante $h=0.01$. Almacenar los puntos de discretización en el vector $\mathbf{x}$ y exhibir $f\left(\mathbf{x}\right)$ en los siguientes casos:
% a. $f(x)=\cos x$, $f(x)=\sqrt{x}, f(x)=\ln x$.
% b. Usando el comando `linspace` para generar discretizaciones del intervalo $\left[1,2\right]$.
% c. Usar una matriz con dos columnas: en la primera almacenar $\mathbf{x}$ y en la otra almacenar $f(\mathbf{x})$.
%
% 10. Usando el comando `pĺot(x,y,'o')`, `pĺot(x,y,'ro-')` plotear
% a. los puntos $\left(2,3\right), \left(4,5\right), \left(8,5\right), \left(9,4\right)$.
% b. la poligonal que une los puntos $\left(2,3\right), \left(4,5\right), \left(8,5\right), \left(9,4\right)$ en ese orden.
%
% 11. Graficar la función $y=xe^{-x^2}$ en el intervalo $\left[-2,2\right]$.
%
% 12. Mostrar las gráficas de las funciones $f(t)=Ce^t-t-1$, $C=-1,0,1,2,3$ en un mismo plano, en el intervalo $0\le t\le 2$.
%
% 13. Implementar el programa `PL2` en MATLAB que calcule la proyección $L^2$ de una función.
%
% 14. Use el programa `PL2` para calcular la proyección de las siguientes funciones:
% a. $f(x)=2x\mathrm{sen}\left(2\pi x\right)+3$, $x\in\left[0,1\right]$.
% b. $f(x)=1$, $x\in\left[0,1\right]$.
% c. $f(x)=x^3\left(x-1\right)\left(1-2x\right)$, $x\in\left[0,1\right]$.
% d. $f(x)=\arctan\left(\frac{\left(x-0.5\right)}{\varepsilon}\right)$, $x\in\left[0,1\right]$, para $\varepsilon\in\left\{0.1, 0.01\right\}$.

% %%
% Solución 1
clc, clear all;
b = [8 -7 6 3 4]'
% Parte a
for i=1:3
    b(i)
end
% Parte b
b_b = b(2:4)
% Out:
% b =
%
%      8
%     -7
%      6
%      3
%      4
%
%
% ans =
%
%      8
%
%
% ans =
%
%     -7
%
%
% ans =
%
%      6
%
%
% b_b =
%
%     -7
%      6
%      3

% %%
clc, clear all;
% Solución 2
A =[7 3 5 -6;
    3 4 4 2;
    1 -1 2 -5]
% Parte a
for i=1:3
    for j=1:4
        A(i,j)
    end
end
% Parte b
% Out:
% A =
%
%      7     3     5    -6
%      3     4     4     2
%      1    -1     2    -5
%
%
% ans =
%
%      7
%
%
% ans =
%
%      3
%
%
% ans =
%
%      5
%
%
% ans =
%
%     -6
%
%
% ans =
%
%      3
%
%
% ans =
%
%      4
%
%
% ans =
%
%      4
%
%
% ans =
%
%      2
%
%
% ans =
%
%      1
%
%
% ans =
%
%     -1
%
%
% ans =
%
%      2
%
%
% ans =
%
%     -5
